# %% [markdown]
# **Modin pandas
#
# The modin. pandas DataFrame is an extremely light-weight parallel DataFrame. Modin transparently distributes the data and computation so that all you need to do is continue using the pandas API as you were before installing Modin.

# %%
# !pip install modin[ray]
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.12.3 requires grpcio>=1.48.2, but you have grpcio 1.43.0 which is incompatible.
# google-auth-oauthlib 1.0.0 requires google-auth>=2.15.0, but you have google-auth 1.35.0 which is incompatible.
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.3
#     Uninstalling protobuf-4.23.3:
#       Successfully uninstalled protobuf-4.23.3
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.21.0
#     Uninstalling google-auth-2.21.0:
#       Successfully uninstalled google-auth-2.21.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.56.0
#     Uninstalling grpcio-1.56.0:
#       Successfully uninstalled grpcio-1.56.0
# ...

# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv("titanic_train.csv")
df
# Out:
# CPU times: total: 0 ns
# Wall time: 5.53 ms
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# %%time
df.groupby("Sex").count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# ...

# %%
import modin.pandas as mp

# %%
# %%time
df_mp = mp.read_csv("titanic_train.csv")
df_mp
# Out:
# CPU times: total: 15.6 ms
# Wall time: 38.5 ms
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# %%time
df_mp.groupby("sub_category").count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\anaconda3\lib\site-packages\modin\logging\logger_metaclass.py:68, in logger_class_wrapper.<locals>.log_wrap(*args, **kwargs)
#      66     logger.info(f"END::PANDAS-API::{class_name}.{method_name}")
#      67     return result
# ---> 68 return method(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\modin\pandas\dataframe.py:445, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#     443         level, by = by, None
#     444     elif level is None:
# --> 445         by = self.__getitem__(by)._query_compiler
#     446 elif isinstance(by, Series):
#     447     drop = by._parent is self
#
# File ~\anaconda3\lib\site-packages\modin\logging\logger_metaclass.py:68, in logger_class_wrapper.<locals>.log_wrap(*args, **kwargs)
# ...
