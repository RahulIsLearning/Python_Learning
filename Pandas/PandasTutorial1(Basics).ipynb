# %%
import pandas as pd

# %% [markdown]
# Creating the pandas Dataframe

# %%
# Using dictionary

data = {
    'id' :[1,2,3,4,5],
    'name':['abc','def','mno','tuv','wxy']
}

df = pd.DataFrame(data)
df
# Out:
#    id name
# 0   1  abc
# 1   2  def
# 2   3  mno
# 3   4  tuv
# 4   5  wxy

# %%
# Reading the file
input_data = pd.read_csv("titanic_train.csv")
input_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# print the number of rows and columns in dataframe
rows, columns = input_data.shape
print("number of rows ",rows)
print("number of columns ",columns)
# Out:
# number of rows  891
# number of columns  12

# %%
# to get the columns of dataframe
print("The columns present are: ")
input_data.columns
# Out:
# The columns present are:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# to print only first 3 columns

data = input_data[['PassengerId','Name', 'Ticket']]
data.head(4)
# Out:
#    PassengerId                                               Name  \
# 0            1                            Braund, Mr. Owen Harris
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3                             Heikkinen, Miss. Laina
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#              Ticket
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803

# %% [markdown]
# DataFrame Basics operations

# %%
input_data['Fare'].mean()
# Out:
# 32.2042079685746

# %%
# print the statistics on given numberical data

input_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# give me the age who is maximum

age_max = input_data[input_data['Age'] == input_data['Age'].max()]
age_max
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S
